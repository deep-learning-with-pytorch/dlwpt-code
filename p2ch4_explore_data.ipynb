# %%
# %%time
# %matplotlib inline
from p2ch4.vis import findMalignantSamples, showNodule
malignantSample_list = findMalignantSamples(limit=30)
# Out:
# 2018-03-04 16:04:28,952 INFO     pid:840 p2ch4.dsets:218:__init__ <p2ch4.dsets.LunaDataset object at 0x7f8fdc280358>: 114396 training samples, 114148 ben, 248 mal
# 0 ('1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', (96.2846726653, 19.0348690723, -88.478440818), True)
# 1 ('1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', (104.81380335, 20.8385087972, -92.6909672057), True)
# 2 ('1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', (106.18, 12.61, -96.81), True)
# 3 ('1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492', (-100.46, 68.01, -230.55), True)
# 4 ('1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', (36.54, 78.1, -122.92), True)
# 5 ('1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', (44.25, 52.17, -110.25), True)
# 6 ('1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', (46.00314143, 47.66525294, -108.4822128), True)
# ...

# %%
malignant_ndx = 20
malignant_ndx = 27
series_uid = malignantSample_list[malignant_ndx][0]
showNodule(series_uid, scaled_bool=True)
# Out:
# 2018-03-04 16:07:23,574 INFO     pid:840 p2ch4.dsets:218:__init__ <p2ch4.dsets.LunaDataset object at 0x7f8f4a38c8d0>: 744 training samples, 743 ben, 1 mal
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912 519 True [519] XyzTuple(x=0.703125, y=0.703125, z=2.5)

# %%
series_uid = malignantSample_list[malignant_ndx][0]
showNodule(series_uid, scaled_bool=False)
# Out:
# 2018-03-04 16:07:37,922 INFO     pid:840 p2ch4.dsets:218:__init__ <p2ch4.dsets.LunaDataset object at 0x7f8f4a220da0>: 744 training samples, 743 ben, 1 mal
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912 519 True [519] XyzTuple(x=0.703125, y=0.703125, z=2.5)
